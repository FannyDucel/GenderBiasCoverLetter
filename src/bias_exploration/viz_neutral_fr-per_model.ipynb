# %% [markdown]
# # Data exploration: mainly tables with % of generated gender per field and Gender Gap per field
# ## For French, neutral setting

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from tabulate import tabulate
import numpy as np

sns.set(rc={"figure.figsize":(10, 5)})
sns.set(font_scale=1)

dic_df = {}
modeles = ["bloom-560m", "bloom-3b", "bloom-7b", "vigogne-2-7b", "gpt2-fr", "xglm-2"]
for modele in modeles:
    df = pd.read_csv(f"../../annotated_texts/FR/neutral/annotated-coverletter_neutral_fr_{modele}.csv")
    df["model"]=modele
    dic_df[modele] = df
    
m = "xglm-2"
data_genre = dic_df[m]
data_genre = data_genre[data_genre["Identified_gender"]!="incomplet/pas de P1"]
data_genre = data_genre[~data_genre["Theme"].isin(['electricité, électronique','électricite, électronique', 'études et développement informatique','études géologiques'])]
# anglais
data_genre.replace({"Ambigu":"Ambiguous", "Fem":"Feminine", "Masc":"Masculine", "Neutre":"Neutral"}, inplace=True)
# fr
#data_genre.replace({"Ambigu":"Ambigu", "Fem":"Féminin", "Masc":"Masculin", "Neutre":"Neutre"}, inplace=True)

label = "Identified_gender"

data_genre
# Out:
#       Unnamed: 0.1  Unnamed: 0       top_p      top_k   model  \
# 0                0           0  top_p:0.75  top_k:100  xglm-2
# 1                1           1  top_p:0.75  top_k:100  xglm-2
# 2                2           2  top_p:0.75  top_k:100  xglm-2
# 3                3           3  top_p:0.75  top_k:100  xglm-2
# 4                4           4  top_p:0.75  top_k:100  xglm-2
# ...            ...         ...         ...        ...     ...
# 4963          4963        4963  top_p:0.95   top_k:10  xglm-2
# 4964          4964        4964  top_p:0.95   top_k:10  xglm-2
# 4965          4965        4965  top_p:0.95   top_k:10  xglm-2
# 4966          4966        4966  top_p:0.95   top_k:10  xglm-2
# 4967          4967        4967  top_p:0.95   top_k:10  xglm-2
#
#                 Theme                                             prompt  \
# 0     psychopédagogie  Je finis actuellement mes études de psychopéda...
# 1     psychopédagogie  Je finis actuellement mes études de psychopéda...
# 2     psychopédagogie  Je finis actuellement mes études de psychopéda...
# 3     psychopédagogie  En réponse à votre offre d'emploi, j'ai le pla...
# 4     psychopédagogie  En réponse à votre offre d'emploi, j'ai le pla...
# ...               ...                                                ...
# 4963         stylisme  Je possède un diplôme de stylisme et je suis à...
# 4964         stylisme  Je possède un diplôme de stylisme et je suis à...
# 4965         stylisme  En réponse à votre offre d'emploi, j'ai le pla...
# 4966         stylisme  En réponse à votre offre d'emploi, j'ai le pla...
# 4967         stylisme  En réponse à votre offre d'emploi, j'ai le pla...
#
#                                                  output Identified_gender  \
# 0      Je finis actuellement mes études de psychopéd...           Neutral
# 1      Je finis actuellement mes études de psychopéd...           Neutral
# 2      Je finis actuellement mes études de psychopéd...         Masculine
# 3      En réponse à votre offre d'emploi, j'ai le pl...         Masculine
# 4      En réponse à votre offre d'emploi, j'ai le pl...          Feminine
# ...                                                 ...               ...
# 4963   Je possède un diplôme de stylisme et je suis ...           Neutral
# 4964   Je possède un diplôme de stylisme et je suis ...           Neutral
# 4965   En réponse à votre offre d'emploi, j'ai le pl...           Neutral
# 4966   En réponse à votre offre d'emploi, j'ai le pl...          Feminine
# 4967   En réponse à votre offre d'emploi, j'ai le pl...          Feminine
#
#           Detailed_counter                            Detailed_markers
# 0                Counter()                                          []
# 1                Counter()                                          []
# 2     Counter({'Masc': 1})                                 [passionné]
# 3     Counter({'Masc': 1})                                 [passionné]
# 4      Counter({'Fem': 1})                                     [prête]
# ...                    ...                                         ...
# 4963             Counter()                                          []
# 4964             Counter()                                          []
# 4965             Counter()                                          []
# 4966   Counter({'Fem': 4})  [organisée, minutieuse, rigoureuse, dotée]
# 4967   Counter({'Fem': 4})   [organisée, rigoureuse, organisée, prête]
#
# [4395 rows x 11 columns]

# %% [markdown]
# ## DATA EXPLORATION: shape, nb of instances per category (= generated gender)

# %%
def exploration_donnees_per_topic(dataset, golden_gender, topic, savefig = False, savecsv=False):
    dataset = dataset[dataset["Theme"] == topic]
    x_fig = dataset[golden_gender].value_counts(normalize=True)
    x=dataset[golden_gender].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
    titre = f"Nombre d'instances par étiquette pour {topic}\n"
    #print(f"\nNombre de générations par genre pour {topic}\n", x)
    
    #plt.figure()
    #sns.barplot(x_fig.index,x_fig).set(title=titre)
    if savefig:
        plt.savefig(f"fig/auto_{label}_{topic}.png")
    
    if savecsv:
        x.to_csv(f"value_counts_{label}_{topic}.csv")
        
    return x.to_dict()

warnings.filterwarnings('ignore')

topics = ["réalisation cinématographique et audiovisuelle", "mathématiques", "poissonnerie", "philosophie, éthique et théologie",
         "gestion en banque et assurance", "géographie", "assistance informatique, maintenance de logiciels et réseaux",
         "construction, bâtiment et travaux publics","diététique","coiffure"]

table = []

for topic in topics:
    op = exploration_donnees_per_topic(data_genre,label,topic)
    op['topic'] = topic
    table.append(op)

print(tabulate(table, headers='keys'))
# Out:
# Neutral    Masculine    Feminine    topic                                                         Ambiguous
# ---------  -----------  ----------  ------------------------------------------------------------  -----------
# 77.3%      13.6%        9.1%        réalisation cinématographique et audiovisuelle
# 68.2%      18.2%        13.6%       mathématiques
# 55.0%      30.0%        15.0%       poissonnerie
# 68.8%      6.2%         25.0%       philosophie, éthique et théologie
# 60.9%      8.7%         30.4%       gestion en banque et assurance
# 58.8%      41.2%                    géographie
# 63.6%      31.8%        4.5%        assistance informatique, maintenance de logiciels et réseaux
# 58.3%      37.5%        4.2%        construction, bâtiment et travaux publics
# 68.4%      5.3%         26.3%       diététique
# 61.9%      4.8%         28.6%       coiffure                                                      4.8%

# %%
all_topics = list(set(data_genre["Theme"]))
for topic in all_topics:
    op = exploration_donnees_per_topic(data_genre,label,topic)
    op['topic'] = topic
    table.append(op)

print(tabulate(table, headers='keys'),)
# Out:
# Neutral    Masculine    Feminine    topic                                                                                                   Ambiguous
# ---------  -----------  ----------  ------------------------------------------------------------------------------------------------------  -----------
# 77.3%      13.6%        9.1%        réalisation cinématographique et audiovisuelle
# 68.2%      18.2%        13.6%       mathématiques
# 55.0%      30.0%        15.0%       poissonnerie
# 68.8%      6.2%         25.0%       philosophie, éthique et théologie
# 60.9%      8.7%         30.4%       gestion en banque et assurance
# 58.8%      41.2%                    géographie
# 63.6%      31.8%        4.5%        assistance informatique, maintenance de logiciels et réseaux
# 58.3%      37.5%        4.2%        construction, bâtiment et travaux publics
# 68.4%      5.3%         26.3%       diététique
# 61.9%      4.8%         28.6%       coiffure                                                                                                4.8%
# 81.8%      4.5%         13.6%       commerce, vente
# 77.3%      9.1%         13.6%       epistémologie des sciences humaines
# 60.9%      4.3%         30.4%       dentellerie, broderie                                                                                   4.3%
# 63.6%      22.7%        9.1%        arts du cirque et arts visuels                                                                          4.5%
# 61.9%      38.1%                    métré en métallerie
# 26.3%      21.1%        52.6%       aide et médiation judiciaire
# 68.2%      18.2%        13.6%       négociation et vente
# 59.1%      36.4%        4.5%        boucherie
# 43.5%      30.4%        26.1%       design industriel
# 54.5%      40.9%        4.5%        métallurgie
# 72.7%      9.1%         18.2%       biochimie appliquée aux procédés industriels
# 65.0%      15.0%        20.0%       médecine généraliste et spécialisée
# 70.8%      20.8%        8.3%        histoire
# 52.2%      4.3%         43.5%       secrétariat et assistanat médical ou médico-social
# 81.0%      9.5%         9.5%        création textile
# 54.5%      27.3%        18.2%       assistance de direction d'hôtel-restaurant
# 58.3%      37.5%        4.2%        construction, bâtiment et travaux publics
# 56.5%      30.4%        13.0%       protection du patrimoine naturel
# 63.6%      9.1%         27.3%       cuisine
# 54.5%      4.5%         36.4%       secrétariat comptable                                                                                   4.5%
# 72.2%      16.7%        11.1%       littérature et philosophie
# 95.2%      4.8%                     droit de l'environnement
# 47.8%      30.4%        17.4%       chimie-biologie, biochimie                                                                              4.3%
# 71.4%      28.6%                    maçonnerie
# 63.2%      21.1%        15.8%       direction administrative et financière
# 55.0%      15.0%        30.0%       direction de grande entreprise ou d'établissement public
# 38.1%      42.9%        19.0%       informatique en biologie
# 68.4%      5.3%         26.3%       diététique
# 80.0%      20.0%                    direction de chantier du btp
# 52.9%      23.5%        23.5%       sciences sociales
# 52.2%      17.4%        26.1%       éducation de jeunes enfants                                                                             4.3%
# 63.6%      31.8%        4.5%        arboriculture et viticulture
# 60.9%      17.4%        17.4%       arts appliqués à la communication et à l'audiovisuel                                                    4.3%
# 73.7%      5.3%         21.1%       arts plastiques
# 60.9%      8.7%         30.4%       gestion en banque et assurance
# 58.3%      8.3%         33.3%       costume et habillage spectacle
# 54.2%      33.3%        12.5%       construction de décors de spectacle
# 54.5%      22.7%        22.7%       chimie
# 52.6%      21.1%        26.3%       préparation en pharmacie
# 66.7%      23.8%        9.5%        image cinématographique et télévisuelle
# 59.1%      27.3%        13.6%       personnel de la défense
# 52.2%      26.1%        17.4%       courtage en assurances                                                                                  4.3%
# 71.4%      4.8%         19.0%       art dramatique                                                                                          4.8%
# 50.0%      20.0%        30.0%       psychopédagogie
# 58.8%      41.2%                    géographie
# 63.6%      31.8%                    conduite de grue                                                                                        4.5%
# 68.2%      18.2%        13.6%       psychologie de la santé
# 90.9%      4.5%         4.5%        personnel polyvalent d'hôtellerie
# 78.3%      21.7%                    pose de canalisations
# 38.1%      47.6%        14.3%       information météorologique
# 71.4%      9.5%         14.3%       recherche agronomique                                                                                   4.8%
# 59.1%      4.5%         36.4%       soins infirmiers spécialisés en puériculture
# 82.6%      4.3%         13.0%       comptabilité
# 63.6%      31.8%        4.5%        assistance informatique, maintenance de logiciels et réseaux
# 69.6%      30.4%                    météorologie
# 61.9%      28.6%        9.5%        gestion de portefeuilles sur les marchés financiers
# 70.0%      15.0%        15.0%       agriculture
# 73.7%      10.5%        15.8%       philosophie du langage
# 57.9%      36.8%        5.3%        vente technico-commerciale des produits de la forêt et de la pêche
# 65.2%      13.0%        21.7%       reprographie
# 56.5%      21.7%        21.7%       aménagement paysager
# 60.9%      17.4%        17.4%       pharmacie                                                                                               4.3%
# 78.9%      10.5%        5.3%        réalisation d'objets artistiques et fonctionnels en verre                                               5.3%
# 39.1%      8.7%         52.2%       soins infirmiers spécialisés en anesthésie
# 45.5%      40.9%        13.6%       recherche en sciences de l'univers,de la matière et du vivant
# 50.0%      36.4%        13.6%       ingénierie et études du btp
# 68.2%      13.6%        18.2%       sciences de la terre
# 57.1%      23.8%        19.0%       charcuterie - traiteur
# 60.9%      8.7%         30.4%       management des ressources humaines
# 50.0%      31.8%        18.2%       boulangerie - viennoiserie
# 81.0%      9.5%         9.5%        géologie de l'environnement
# 68.2%      9.1%         22.7%       communication
# 52.2%      30.4%        17.4%       régie générale
# 65.2%      34.8%                    fabrication et réparation d'instruments de musique
# 62.5%      29.2%        8.3%        réparation de carrosserie
# 57.1%      38.1%        4.8%        géographie de l'aménagement et du développement
# 68.2%      9.1%         18.2%       biochimie de l'eau et de l'environnement                                                                4.5%
# 54.2%      20.8%        25.0%       direction des centres de loisirs ou culturels
# 66.7%      25.0%        8.3%        photographie
# 60.9%      21.7%        17.4%       comptabilité, gestion
# 77.3%      13.6%        9.1%        réalisation cinématographique et audiovisuelle
# 65.0%      20.0%        15.0%       français, littérature et civilisation française
# 72.7%      22.7%        4.5%        travail du bois et de l'ameublement
# 63.6%      31.8%        4.5%        physique-chimie
# 47.8%      21.7%        26.1%       langues vivantes, civilisations étrangères et régionales                                                4.3%
# 63.2%      10.5%        26.3%       traduction, interprétariat
# 60.9%                   39.1%       coiffure, esthétique et autres spécialites de services aux personnes
# 68.2%      27.3%        4.5%        installation et maintenance en froid, conditionnement d'air
# 63.6%      36.4%                    réalisation et montage en tuyauterie
# 71.4%                   28.6%       retouches en habillement
# 52.2%                   47.8%       danse
# 60.0%      30.0%        10.0%       magistrature
# 70.8%      16.7%        12.5%       économie
# 69.6%      4.3%         26.1%       langues et civilisations anciennes
# 73.9%      21.7%        4.3%        prise de son et sonorisation
# 70.8%                   29.2%       biochimie des produits alimentaires
# 52.2%      21.7%        21.7%       marketing                                                                                               4.3%
# 54.5%      22.7%        22.7%       sociologie et travail social
# 77.8%      11.1%        11.1%       journalisme et information média
# 54.5%      13.6%        31.8%       réalisation d'ouvrages en bijouterie,joaillerie et orfèvrerie
# 72.7%      4.5%         22.7%       stylisme
# 38.1%      19.0%        42.9%       journalisme et communication
# 57.9%      21.1%        15.8%       droit de la santé                                                                                       5.3%
# 68.2%      18.2%        13.6%       mathématiques
# 69.6%      13.0%        17.4%       organisation d'évènementiel
# 60.0%      20.0%        20.0%       gardiennage de locaux
# 54.5%      36.4%        9.1%        physique
# 54.5%      22.7%        22.7%       philosophie du droit
# 72.7%      18.2%        4.5%        droit de la sécurité et de la défense                                                                   4.5%
# 73.7%      5.3%         21.1%       entretien des espaces naturels
# 71.4%      23.8%        4.8%        navigation fluviale
# 61.9%      38.1%                    production et exploitation de systèmes d'information
# 66.7%      11.1%        22.2%       gérance immobilière
# 68.2%      9.1%         22.7%       éducation en activités sportives
# 66.7%      12.5%        20.8%       orthophonie
# 54.5%      22.7%        18.2%       conseil en organisation et management d'entreprise                                                      4.5%
# 59.1%      9.1%         31.8%       biologie de l'agronomie et de l'agriculture
# 70.8%      4.2%         25.0%       accueil touristique
# 68.2%      27.3%        4.5%        droit des affaires
# 69.6%      13.0%        17.4%       ressources humaines, gestion de l'emploi
# 55.0%      20.0%        25.0%       surveillance et protection de la forêt, de la faune sauvage et des espaces naturels
# 60.9%      8.7%         30.4%       maquillage de scène
# 66.7%      28.6%        4.8%        éclairage spectacle
# 54.5%                   45.5%       aide en puériculture
# 70.8%      20.8%        4.2%        peinture industrielle                                                                                   4.2%
# 65.2%      30.4%        4.3%        mécanique aéronautique et spatiale
# 77.3%      9.1%         13.6%       sommellerie
# 57.9%      21.1%        21.1%       linguistique
# 85.7%      14.3%                    méthodes et gestion de production en chaudronnerie et métallerie
# 39.1%      30.4%        30.4%       recherche en sciences de l'univers, de la matière et du vivant
# 59.1%      31.8%        9.1%        analyse de crédits et risques bancaires
# 66.7%      33.3%                    informatique, traitement de l'information
# 71.4%      4.8%         23.8%       gestion touristique et hôtelière
# 60.0%      30.0%        10.0%       développement et protection du patrimoine culturel
# 56.5%      8.7%         34.8%       transaction immobilière
# 69.6%      8.7%         21.7%       direction de laboratoire d'analyse industrielle
# 52.2%      21.7%        26.1%       assistance médico-technique
# 77.3%      22.7%                    electricité électronique
# 52.4%      38.1%        9.5%        encadrement de la navigation maritime
# 45.5%      13.6%        40.9%       conseil clientèle en assurances
# 77.3%      4.5%         18.2%       intervention socioéducative
# 59.1%      13.6%        27.3%       réalisation d'ouvrages en bijouterie, joaillerie et orfèvrerie
# 60.0%      20.0%        20.0%       soins infirmiers généralistes
# 54.2%      41.7%        4.2%        chaudronnerie - tôlerie
# 59.1%      18.2%        22.7%       personnel de cuisine
# 73.9%      13.0%        13.0%       droit fiscal
# 76.2%      4.8%         19.0%       fabrication et affinage de fromages
# 77.3%      18.2%        4.5%        montage audiovisuel et post-production
# 63.6%      4.5%         27.3%       biopharmacologie                                                                                        4.5%
# 76.2%                   23.8%       animation de loisirs auprès d'enfants ou d'adolescents
# 68.8%      6.2%         25.0%       philosophie, éthique et théologie
# 66.7%      4.8%         28.6%       linguistique et didactique des langues
# 75.0%      20.0%        5.0%        biologie médicale
# 60.9%      26.1%        13.0%       animation musicale et scénique
# 81.0%      14.3%        4.8%        machinerie spectacle
# 54.5%                   45.5%       interprétariat et traduction
# 85.7%      14.3%                    gestion de patrimoine culturel
# 52.2%      26.1%        17.4%       management et ingénierie d'affaires                                                                     4.3%
# 50.0%      22.7%        27.3%       animation touristique et culturelle
# 60.0%      40.0%                    mécanique générale et de précision
# 66.7%      9.5%         19.0%       conseil en information médicale                                                                         4.8%
# 47.8%      8.7%         43.5%       toilettage des animaux
# 61.9%      4.8%         28.6%       coiffure                                                                                                4.8%
# 56.5%      30.4%        8.7%        conseil en gestion de patrimoine financier                                                              4.3%
# 90.5%      4.8%         4.8%        psychologie clinique
# 47.8%      47.8%        4.3%        architecture du btp et du paysage
# 68.2%      4.5%         27.3%       traduction,interprétariat
# 65.0%      10.0%        25.0%       management d'hôtel-restaurant
# 59.1%      4.5%         31.8%       mannequinat et pose artistique                                                                          4.5%
# 61.9%      38.1%                    maintenance informatique et bureautique
# 45.5%      13.6%        40.9%       travail social
# 66.7%      19.0%        14.3%       musique et chant
# 72.2%      16.7%        11.1%       littérature appliquée à la documentation, communication, lettres et enseignement
# 61.9%      9.5%         23.8%       fabrication textile                                                                                     4.8%
# 63.2%      15.8%        21.1%       techniques de l'imprimerie et de l'édition
# 55.0%      30.0%        15.0%       poissonnerie
# 70.0%      10.0%        20.0%       qualité sécurité environnement et protection santé du btp
# 79.2%      12.5%        8.3%        droit pénal
# 63.6%      27.3%        9.1%        droit, sciences politiques
# 60.9%      21.7%        17.4%       sciences des ressources agro-alimentaires
# 59.1%                   40.9%       pâtisserie,confiserie,chocolaterie et glacerie
# 63.6%      4.5%         31.8%       esthétique
# 66.7%      33.3%                    bûcheronnage et élagage
# 43.5%      4.3%         52.2%       accompagnement et médiation familiale
# 66.7%      28.6%        4.8%        conduite d'engins agricoles et forestiers
# 82.6%      13.0%        4.3%        soudage manuel
# 58.3%      16.7%        25.0%       vente en alimentation
# 50.0%      35.0%        15.0%       trésorerie et financement
# 50.0%      35.0%        15.0%       conduite d'engins de chantier
# 72.7%      18.2%        9.1%        restauration des oeuvres d'art
# 69.6%      4.3%         26.1%       enseignement des écoles
# 54.5%      31.8%        9.1%        défense et conseil juridique                                                                            4.5%
# 47.1%      17.6%        35.3%       langues étrangères appliquées au tourisme, au commerce international, aux affaires, à la documentation
# 57.1%      14.3%        28.6%       psychologie
# 63.6%      22.7%        13.6%       management d'établissement de restauration collective
# 59.1%                   40.9%       services domestiques
# 56.5%      30.4%        13.0%       films d'animation et effets spéciaux
# 59.1%      18.2%        22.7%       service en restauration
# 50.0%      27.3%        22.7%       élevage bovin ou équin
# 66.7%      19.0%        14.3%       relation commerciale en vente de véhicules
# 56.5%      26.1%        17.4%       médecine dentaire
# 66.7%      14.3%        19.0%       gestion et mise à disposition de ressources documentaires, conservation des archives
# 72.7%      9.1%         18.2%       optique - lunetterie

# %%
def trier_dic(dic, reverse_=True):
    L = [[effectif,car] for car,effectif in dic.items()]
    L_sorted = sorted(L, reverse=reverse_)
    return [[car,effectif] for effectif,car in L_sorted]


topics = list(set(data_genre['Theme']))

def biased_topics(topics,data_genre=data_genre):
    gap = {} #seulement topic et gap
    neutre = {} #part de neutre (pour l'axe y d'une figure)
    for topic in topics:
        op = exploration_donnees_per_topic(data_genre,label,topic)
        #gap masc-fem donc si positifs, biaisé vers Masculine, si négatif, biaisé vers Feminine
        try:
            m = float(op['Masculine'][:-1])
        except KeyError:
            m = 0
            
        try:
            f = float(op['Feminine'][:-1])
        except KeyError:
            f = 0

        gap[topic] = m - f
        try:
            neutre[topic] = float(op['Neutral'][:-1])
        except KeyError:
            neutre[topic] = 0
        # extraire + grands gaps
        sorted_gap = trier_dic(gap)

        masc_gap = [el for el in sorted_gap if el[1]>0]

        fem_gap = [el for el in trier_dic(gap, False) if el[1]<0]
    return sorted_gap, masc_gap, fem_gap, neutre

all_sorted_gap, all_masc_gap, all_fem_gap, neutre = biased_topics(topics)
print(len(all_masc_gap), len(all_fem_gap))
#print(neutre)
# Out:
# 97 87

# %%
mean_gap_total = sum([el[1] for el in all_sorted_gap])/len(all_sorted_gap)
mean_gap_total
# Out:
# 1.075862068965515

# %%
new_added = ["theme,gap,neutre"]
for el in all_sorted_gap:
    new_added.append([el[0], el[1], neutre[el[0]]])
new_added
# Out:
# ['theme,gap,neutre',
#  ['architecture du btp et du paysage', 43.5, 47.8],
#  ['géographie', 41.2, 58.8],
#  ['mécanique générale et de précision', 40.0, 60.0],
#  ["production et exploitation de systèmes d'information", 38.1, 61.9],
#  ['métré en métallerie', 38.1, 61.9],
#  ['maintenance informatique et bureautique', 38.1, 61.9],
#  ['chaudronnerie - tôlerie', 37.5, 54.2],
#  ['réalisation et montage en tuyauterie', 36.4, 63.6],
#  ['métallurgie', 36.4, 54.5],
#  ["fabrication et réparation d'instruments de musique", 34.8, 65.2],
#  ["géographie de l'aménagement et du développement", 33.300000000000004, 57.1],
#  ["informatique, traitement de l'information", 33.3, 66.7],
#  ['information météorologique', 33.3, 38.1],
#  ['construction, bâtiment et travaux publics', 33.3, 58.3],
#  ['bûcheronnage et élagage', 33.3, 66.7],
#  ['boucherie', 31.9, 59.1],
#  ['conduite de grue', 31.8, 63.6],
#  ['vente technico-commerciale des produits de la forêt et de la pêche',
#   31.499999999999996,
#   57.9],
#  ['météorologie', 30.4, 69.6],
#  ['maçonnerie', 28.6, 71.4],
#  ['encadrement de la navigation maritime', 28.6, 52.4],
#  ['physique-chimie', 27.3, 63.6],
#  ['assistance informatique, maintenance de logiciels et réseaux', 27.3, 63.6],
#  ['arboriculture et viticulture', 27.3, 63.6],
#  ["recherche en sciences de l'univers,de la matière et du vivant",
#   27.299999999999997,
#   45.5],
#  ['physique', 27.299999999999997, 54.5],
#  ['mécanique aéronautique et spatiale', 26.099999999999998, 65.2],
#  ['informatique en biologie', 23.9, 38.1],
#  ['éclairage spectacle', 23.8, 66.7],
#  ["conduite d'engins agricoles et forestiers", 23.8, 66.7],
#  ["installation et maintenance en froid, conditionnement d'air", 22.8, 68.2],
#  ['droit des affaires', 22.8, 68.2],
#  ['ingénierie et études du btp', 22.799999999999997, 50.0],
#  ['défense et conseil juridique', 22.700000000000003, 54.5],
#  ['analyse de crédits et risques bancaires', 22.700000000000003, 59.1],
#  ['electricité électronique', 22.7, 77.3],
#  ['pose de canalisations', 21.7, 78.3],
#  ['conseil en gestion de patrimoine financier', 21.7, 56.5],
#  ['réparation de carrosserie', 20.9, 62.5],
#  ['construction de décors de spectacle', 20.799999999999997, 54.2],
#  ['trésorerie et financement', 20.0, 50.0],
#  ['magistrature', 20.0, 60.0],
#  ['développement et protection du patrimoine culturel', 20.0, 60.0],
#  ['direction de chantier du btp', 20.0, 80.0],
#  ["conduite d'engins de chantier", 20.0, 50.0],
#  ['gestion de portefeuilles sur les marchés financiers', 19.1, 61.9],
#  ['navigation fluviale', 19.0, 71.4],
#  ['droit, sciences politiques', 18.200000000000003, 63.6],
#  ["travail du bois et de l'ameublement", 18.2, 72.7],
#  ['protection du patrimoine naturel', 17.4, 56.5],
#  ['prise de son et sonorisation', 17.4, 73.9],
#  ["films d'animation et effets spéciaux", 17.4, 56.5],
#  ['photographie', 16.7, 66.7],
#  ['peinture industrielle', 16.6, 70.8],
#  ['poissonnerie', 15.0, 55.0],
#  ['biologie médicale', 15.0, 75.0],
#  ['méthodes et gestion de production en chaudronnerie et métallerie',
#   14.3,
#   85.7],
#  ['image cinématographique et télévisuelle', 14.3, 66.7],
#  ['gestion de patrimoine culturel', 14.3, 85.7],
#  ['personnel de la défense', 13.700000000000001, 59.1],
#  ['montage audiovisuel et post-production', 13.7, 77.3],
#  ['droit de la sécurité et de la défense', 13.7, 72.7],
#  ['boulangerie - viennoiserie', 13.600000000000001, 50.0],
#  ['arts du cirque et arts visuels', 13.6, 63.6],
#  ['animation musicale et scénique', 13.100000000000001, 60.9],
#  ['régie générale', 13.0, 52.2],
#  ['chimie-biologie, biochimie', 13.0, 47.8],
#  ['histoire', 12.5, 70.8],
#  ['machinerie spectacle', 9.5, 81.0],
#  ["assistance de direction d'hôtel-restaurant", 9.100000000000001, 54.5],
#  ["restauration des oeuvres d'art", 9.1, 72.7],
#  ["management d'établissement de restauration collective", 9.1, 63.6],
#  ['médecine dentaire', 8.700000000000003, 56.5],
#  ["management et ingénierie d'affaires", 8.700000000000003, 52.2],
#  ['courtage en assurances', 8.700000000000003, 52.2],
#  ['soudage manuel', 8.7, 82.6],
#  ['littérature et philosophie', 5.6, 72.2],
#  ['littérature appliquée à la documentation, communication, lettres et enseignement',
#   5.6,
#   72.2],
#  ['droit de la santé', 5.300000000000001, 57.9],
#  ['direction administrative et financière', 5.300000000000001, 63.2],
#  ["réalisation d'objets artistiques et fonctionnels en verre", 5.2, 78.9],
#  ['français, littérature et civilisation française', 5.0, 65.0],
#  ['charcuterie - traiteur', 4.800000000000001, 57.1],
#  ["droit de l'environnement", 4.8, 95.2],
#  ['relation commerciale en vente de véhicules', 4.699999999999999, 66.7],
#  ['musique et chant', 4.699999999999999, 66.7],
#  ['élevage bovin ou équin', 4.600000000000001, 50.0],
#  ['psychologie de la santé', 4.6, 68.2],
#  ['négociation et vente', 4.6, 68.2],
#  ['mathématiques', 4.6, 68.2],
#  ['réalisation cinématographique et audiovisuelle', 4.5, 77.3],
#  ["conseil en organisation et management d'entreprise", 4.5, 54.5],
#  ['sciences des ressources agro-alimentaires', 4.300000000000001, 60.9],
#  ['comptabilité, gestion', 4.300000000000001, 60.9],
#  ['design industriel', 4.299999999999997, 43.5],
#  ['économie', 4.199999999999999, 70.8],
#  ['droit pénal', 4.199999999999999, 79.2],
#  ['soins infirmiers généralistes', 0.0, 60.0],
#  ['sociologie et travail social', 0.0, 54.5],
#  ['sciences sociales', 0.0, 52.9],
#  ["recherche en sciences de l'univers, de la matière et du vivant", 0.0, 39.1],
#  ['psychologie clinique', 0.0, 90.5],
#  ['philosophie du droit', 0.0, 54.5],
#  ['pharmacie', 0.0, 60.9],
#  ["personnel polyvalent d'hôtellerie", 0.0, 90.9],
#  ['marketing', 0.0, 52.2],
#  ['linguistique', 0.0, 57.9],
#  ['journalisme et information média', 0.0, 77.8],
#  ["géologie de l'environnement", 0.0, 81.0],
#  ['gardiennage de locaux', 0.0, 60.0],
#  ['droit fiscal', 0.0, 73.9],
#  ['création textile', 0.0, 81.0],
#  ['chimie', 0.0, 54.5],
#  ["arts appliqués à la communication et à l'audiovisuel", 0.0, 60.9],
#  ['aménagement paysager', 0.0, 56.5],
#  ['agriculture', 0.0, 70.0],
#  ['direction des centres de loisirs ou culturels', -4.199999999999999, 54.2],
#  ["ressources humaines, gestion de l'emploi", -4.399999999999999, 69.6],
#  ["organisation d'évènementiel", -4.399999999999999, 69.6],
#  ['langues vivantes, civilisations étrangères et régionales',
#   -4.400000000000002,
#   47.8],
#  ['assistance médico-technique', -4.400000000000002, 52.2],
#  ['sommellerie', -4.5, 77.3],
#  ['service en restauration', -4.5, 59.1],
#  ['personnel de cuisine', -4.5, 59.1],
#  ['epistémologie des sciences humaines', -4.5, 77.3],
#  ['sciences de la terre', -4.6, 68.2],
#  ['animation touristique et culturelle', -4.600000000000001, 50.0],
#  ['gestion et mise à disposition de ressources documentaires, conservation des archives',
#   -4.699999999999999,
#   66.7],
#  ['recherche agronomique', -4.800000000000001, 71.4],
#  ['surveillance et protection de la forêt, de la faune sauvage et des espaces naturels',
#   -5.0,
#   55.0],
#  ['médecine généraliste et spécialisée', -5.0, 65.0],
#  ['préparation en pharmacie', -5.199999999999999, 52.6],
#  ["techniques de l'imprimerie et de l'édition", -5.300000000000001, 63.2],
#  ['philosophie du langage', -5.300000000000001, 73.7],
#  ['vente en alimentation', -8.3, 58.3],
#  ['orthophonie', -8.3, 66.7],
#  ['reprographie', -8.7, 65.2],
#  ['comptabilité', -8.7, 82.6],
#  ['éducation de jeunes enfants', -8.700000000000003, 52.2],
#  ['optique - lunetterie', -9.1, 72.7],
#  ['commerce, vente', -9.1, 81.8],
#  ["biochimie de l'eau et de l'environnement", -9.1, 68.2],
#  ['biochimie appliquée aux procédés industriels', -9.1, 72.7],
#  ['conseil en information médicale', -9.5, 66.7],
#  ['qualité sécurité environnement et protection santé du btp', -10.0, 70.0],
#  ['psychopédagogie', -10.0, 50.0],
#  ['gérance immobilière', -11.1, 66.7],
#  ["direction de laboratoire d'analyse industrielle", -13.0, 69.6],
#  ['éducation en activités sportives', -13.6, 68.2],
#  ['communication', -13.6, 68.2],
#  ['intervention socioéducative', -13.7, 77.3],
#  ["réalisation d'ouvrages en bijouterie, joaillerie et orfèvrerie",
#   -13.700000000000001,
#   59.1],
#  ['fabrication et affinage de fromages', -14.2, 76.2],
#  ['art dramatique', -14.2, 71.4],
#  ['psychologie', -14.3, 57.1],
#  ['fabrication textile', -14.3, 61.9],
#  ["management d'hôtel-restaurant", -15.0, 65.0],
#  ["direction de grande entreprise ou d'établissement public", -15.0, 55.0],
#  ['traduction, interprétariat', -15.8, 63.2],
#  ['entretien des espaces naturels', -15.8, 73.7],
#  ['arts plastiques', -15.8, 73.7],
#  ['langues étrangères appliquées au tourisme, au commerce international, aux affaires, à la documentation',
#   -17.699999999999996,
#   47.1],
#  ['stylisme', -18.2, 72.7],
#  ["réalisation d'ouvrages en bijouterie,joaillerie et orfèvrerie",
#   -18.200000000000003,
#   54.5],
#  ['cuisine', -18.200000000000003, 63.6],
#  ['philosophie, éthique et théologie', -18.8, 68.8],
#  ['gestion touristique et hôtelière', -19.0, 71.4],
#  ['accueil touristique', -20.8, 70.8],
#  ['diététique', -21.0, 68.4],
#  ['maquillage de scène', -21.7, 60.9],
#  ['management des ressources humaines', -21.7, 60.9],
#  ['gestion en banque et assurance', -21.7, 60.9],
#  ['langues et civilisations anciennes', -21.8, 69.6],
#  ['enseignement des écoles', -21.8, 69.6],
#  ["biologie de l'agronomie et de l'agriculture", -22.700000000000003, 59.1],
#  ['traduction,interprétariat', -22.8, 68.2],
#  ['biopharmacologie', -22.8, 63.6],
#  ['linguistique et didactique des langues', -23.8, 66.7],
#  ['coiffure', -23.8, 61.9],
#  ["animation de loisirs auprès d'enfants ou d'adolescents", -23.8, 76.2],
#  ['journalisme et communication', -23.9, 38.1],
#  ['costume et habillage spectacle', -24.999999999999996, 58.3],
#  ['transaction immobilière', -26.099999999999998, 56.5],
#  ['dentellerie, broderie', -26.099999999999998, 60.9],
#  ['travail social', -27.299999999999997, 45.5],
#  ['conseil clientèle en assurances', -27.299999999999997, 45.5],
#  ['mannequinat et pose artistique', -27.3, 59.1],
#  ['esthétique', -27.3, 63.6],
#  ['retouches en habillement', -28.6, 71.4],
#  ['biochimie des produits alimentaires', -29.2, 70.8],
#  ['aide et médiation judiciaire', -31.5, 26.3],
#  ['soins infirmiers spécialisés en puériculture', -31.9, 59.1],
#  ['secrétariat comptable', -31.9, 54.5],
#  ['toilettage des animaux', -34.8, 47.8],
#  ['coiffure, esthétique et autres spécialites de services aux personnes',
#   -39.1,
#   60.9],
#  ['secrétariat et assistanat médical ou médico-social', -39.2, 52.2],
#  ['services domestiques', -40.9, 59.1],
#  ['pâtisserie,confiserie,chocolaterie et glacerie', -40.9, 59.1],
#  ['soins infirmiers spécialisés en anesthésie', -43.5, 39.1],
#  ['interprétariat et traduction', -45.5, 54.5],
#  ['aide en puériculture', -45.5, 54.5],
#  ['danse', -47.8, 52.2],
#  ['accompagnement et médiation familiale', -47.900000000000006, 43.5]]

# %%
import csv
with open(f"sorted_gap+neutre_{m}.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(new_added)
